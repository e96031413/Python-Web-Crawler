# %%
import pandas as pd

# %%
df=pd.read_excel("All IT eBooks.xlsx")

# %%
df.head()
# Out:
#                                        BookName
# 0               Introducing Markdown and Pandoc
# 1   Photoshop Elements 9 All-in-One For Dummies
# 2  Photoshop Elements 13 All-in-One For Dummies
# 3                  Micro:bit for Mad Scientists
# 4      Demystifying Internet of Things Security

# %%
df.describe()
# Out:
#                                    BookName
# count                                  8305
# unique                                 8243
# top     Word 2013 eLearning Kit For Dummies
# freq                                      2

# %%
str_choice = "Android" 
python=df[df['BookName'].str.contains(str_choice, na=False)]

# %%
python.describe()
# Out:
#                                     BookName
# count                                    220
# unique                                   218
# top     Beginning Android Games, 3rd Edition
# freq                                       2

# %%
python.head(50)
# Out:
#                                                BookName
# 21                   Android Studio IDE Quick Reference
# 118                Learn Kotlin for Android Development
# 180                       RxJava for Android Developers
# 322   Xamarin Mobile Application Development for And...
# 337                           Android Espresso Revealed
# 370        Android 3.0 Application Development Cookbook
# 376          Starting Out With App Inventor for Android
# 381            Android Tablets For Dummies, 2nd Edition
# 493                  Learn Android Studio 3 with Kotlin
# 510                Android Phones & Tablets For Dummies
# 582                             Pro Android with Kotlin
# 587                   Professional Android, 4th Edition
# 593                                Asynchronous Android
# 854    Android App Development For Dummies, 3rd Edition
# 869                              Learn Android Studio 3
# 903                                   Practical Android
# ...
