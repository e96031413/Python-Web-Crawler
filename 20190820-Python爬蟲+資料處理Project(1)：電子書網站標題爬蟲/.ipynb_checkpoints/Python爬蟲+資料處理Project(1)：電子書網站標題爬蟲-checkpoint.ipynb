# %%
import pandas as pd

# %%
df=pd.read_excel("All IT eBooks.xlsx")

# %%
df.head()
# Out:
#                                        BookName
# 0               Introducing Markdown and Pandoc
# 1   Photoshop Elements 9 All-in-One For Dummies
# 2  Photoshop Elements 13 All-in-One For Dummies
# 3                  Micro:bit for Mad Scientists
# 4      Demystifying Internet of Things Security

# %%
df.describe()
# Out:
#                                     BookName
# count                                   8305
# unique                                  8243
# top     Beginning Android Games, 3rd Edition
# freq                                       2

# %%
str_choice = "Python | Machine Learning | Deep Learning" 
python=df[df['BookName'].str.contains(str_choice, na=False)]

# %%
python.describe()
# Out:
#                                                  BookName
# count                                                 188
# unique                                                187
# top     Python 3 Object-Oriented Programming, Second E...
# freq                                                    2

# %%
python.head(50)
# Out:
#                                                BookName
# 18                    Data Science with Python and Dask
# 155                       Python All-in-One For Dummies
# 184                    Python Crash Course, 2nd Edition
# 272                      PowerShell and Python Together
# 297                           Pro Python 3, 3rd Edition
# 343     Practical Machine Learning and Image Processing
# 390        MATLAB Machine Learning Recipes, 2nd Edition
# 427          Python Continuous Integration and Delivery
# 437                  The Quick Python Book, 3rd Edition
# 442       Python for Data Mining Quick Syntax Reference
# 542                     Python Descriptors, 2nd Edition
# 553                  Python Data Analytics, 2nd Edition
# 577                               Applied Deep Learning
# 606                        TensorFlow for Deep Learning
# 610                                  Python For Dummies
# 636                     MySQL Connector/Python Revealed
# ...
